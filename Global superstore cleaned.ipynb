# %% [markdown]
# # Global Superstore Sales Analytics
#
# ## 1. Project Introduction

# %% [markdown]
# The Global Superstore dataset contains sales transactions from different countries, markets, regions, customer segments, categories, and products.
#
# The objective of this project is to clean, analyze, and visualize the sales data to identify important patterns in sales, profit, customers, products, categories, and regions.
#
# Python is used for data cleaning and exploratory data analysis. The cleaned dataset will be further used for SQL analysis and Power BI dashboard development.

# %% [markdown]
# ## 📚 2. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 📂 3. Load the Dataset

# %%
df = pd.read_excel("Global Superstoredata.xlsx")

# %% [markdown]
# ## 📊 4. Data Understanding

# %% [markdown]
# ### First Five Rows

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %% [markdown]
# ### Last Five Rows

# %%
df.tail()
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 51285   29002   IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398  US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470  US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596  MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147  MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment      City       State  ...  \
# 51285    KE-16420   Katrina Edelman    Corporate      Kure   Hiroshima  ...
# 51286    ZC-21910  Zuschuss Carroll     Consumer   Houston       Texas  ...
# 51287    LB-16795    Laurel Beltran  Home Office    Oxnard  California  ...
# 51288    RB-19795        Ross Baird  Home Office  Valinhos   São Paulo  ...
# 51289    MC-18100     Mick Crebagga     Consumer  Tipitapa     Managua  ...
#
#             Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Shape of the Dataset

# %%
df.shape
# Out:
# (51290, 24)

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %% [markdown]
# ### Column Names

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# ### Data Types

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %% [markdown]
# ### Descriptive Statistics

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56430.500000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# ...

# %% [markdown]
# ## 🧹 5. Data Preprocessing

# %% [markdown]
# ### Missing Values

# %%
df["Postal Code"] = df["Postal Code"].astype("Int64")

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %% [markdown]
# ### Duplicate Check

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
duplicate_count = df.duplicated().sum()
print("Duplicate rows:", duplicate_count)
# Out:
# Duplicate rows: 0

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Date Cleaning

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

# %%
df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %% [markdown]
# ### Profit Margin Calculation

# %%
df["Profit Margin"] = np.where(
    df["Sales"] > 0,
    (df["Profit"] / df["Sales"]) * 100,
    0
)

# %% [markdown]
# ### Data Validation

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Duplicate rows:", df.duplicated().sum())
print("Missing values:")
print(df.isnull().sum())
# Out:
# Rows: 51290
# Columns: 25
# Duplicate rows: 0
# Missing values:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# Profit Margin         0
# dtype: int64

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code                Int64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# Profit Margin            float64
# dtype: object

# %% [markdown]
# ## 📈 6. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Sales By Category

# %%
sales = df.groupby("Category")["Sales"].sum()

plt.figure(figsize=(6,4))
plt.bar(sales.index, sales.values)
plt.title("Sales by Category")
plt.show()

# %% [markdown]
# ### Monthly Sales

# %%
monthly = df.groupby(df["Order Date"].dt.month)["Sales"].sum()

plt.plot(monthly.index, monthly.values, marker="o")
plt.title("Monthly Sales")
plt.show()

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(7,5))

numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    annot_kws={"size":8}
)

plt.title("Correlation Heatmap", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Profit by Region

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=df, x="Region", y="Profit")
plt.title("Profit by Region")
plt.show()

# %%
# !pip install openpyxl

# %%
df.to_excel("Global_Superstore_Cleaned.xlsx", index=False)

# %%
df.to_csv("Global_Superstore_Cleaned.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\sruth'
